# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from copy import deepcopy

pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# # CSV
# We will use the Kaggle Food Demand Forecasting dat to demonstrate these major steps
#
# * https://www.kaggle.com/datasets/kannanaikkal/food-demand-forecasting/ (trains csv)

# %%
PATH = "../../data/food_demand"
train_data = pd.read_csv(os.path.join(PATH, "train.csv"), index_col=0)
test_data = pd.read_csv(os.path.join(PATH, "test.csv"), index_col=0)

train_data.head()
# Out:
#          week  center_id  meal_id  checkout_price  base_price  \
# id
# 1379560     1         55     1885          136.83      152.29
# 1466964     1         55     1993          136.83      135.83
# 1346989     1         55     2539          134.86      135.86
# 1338232     1         55     2139          339.50      437.53
# 1448490     1         55     2631          243.50      242.50
#
#          emailer_for_promotion  homepage_featured  num_orders
# id
# 1379560                      0                  0         177
# 1466964                      0                  0         270
# 1346989                      0                  0         189
# 1338232                      0                  0          54
# 1448490                      0                  0          40

# %%
meal_info_df = pd.read_csv(os.path.join(PATH, "meal_info.csv"), index_col=0)
meal_info_df = meal_info_df.reset_index(drop=False)
meal_info_df.tail()
# Out:
#     meal_id category      cuisine
# 46     2956     Fish  Continental
# 47     2104     Fish  Continental
# 48     2444  Seafood  Continental
# 49     2867  Seafood  Continental
# 50     1445  Seafood  Continental

# %%
train_data.tail()
# Out:
#          week  center_id  meal_id  checkout_price  base_price  \
# id
# 1271326   145         61     1543          484.09      484.09
# 1062036   145         61     2304          482.09      482.09
# 1110849   145         61     2664          237.68      321.07
# 1147725   145         61     2569          243.50      313.34
# 1361984   145         61     2490          292.03      290.03
#
#          emailer_for_promotion  homepage_featured  num_orders
# id
# 1271326                      0                  0          68
# 1062036                      0                  0          42
# 1110849                      0                  0         501
# 1147725                      0                  0         729
# 1361984                      0                  0         162

# %%
meal_info_df[['category', 'meal_id']].groupby('category').count()
# Out:
#               meal_id
# category
# Beverages          12
# Biryani             3
# Desert              3
# Extras              3
# Fish                3
# Other Snacks        3
# Pasta               3
# Pizza               3
# Rice Bowl           3
# Salad               3
# Sandwich            3
# Seafood             3
# Soup                3
# Starters            3

# %%
train_data = train_data.merge(meal_info_df, on='meal_id', how='left')

# %%
train_data[['category', 'meal_id']].groupby('category').count().sort_values(by='meal_id', ascending=False)
# Out:
#               meal_id
# category
# Beverages      127890
# Rice Bowl       33408
# Sandwich        33291
# Pizza           33138
# Starters        29941
# Other Snacks    29379
# Desert          29294
# Salad           28559
# Pasta           27694
# Seafood         26916
# Biryani         20614
# Extras          13562
# Soup            12675
# Fish            10187

# %%
train_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 456548 entries, 0 to 456547
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   week                   456548 non-null  int64
#  1   center_id              456548 non-null  int64
#  2   meal_id                456548 non-null  int64
#  3   checkout_price         456548 non-null  float64
#  4   base_price             456548 non-null  float64
#  5   emailer_for_promotion  456548 non-null  int64
#  6   homepage_featured      456548 non-null  int64
#  7   num_orders             456548 non-null  int64
#  8   category               456548 non-null  str
#  9   cuisine                456548 non-null  str
# dtypes: float64(2), int64(6), str(2)
# memory usage: 34.8 MB

# %%
for i in range(146):
    slice = train_data[train_data['week'] == i]
    length = len(slice)
    unique_ids = len(slice['meal_id'].unique())
    if length != unique_ids:
        print(f"Week {i} has more than one entry for some meal_id: {length=}, {unique_ids=}")
# Out:
# Week 1 has more than one entry for some meal_id: length=2922, unique_ids=45
# Week 2 has more than one entry for some meal_id: length=2896, unique_ids=45
# Week 3 has more than one entry for some meal_id: length=2899, unique_ids=45
# Week 4 has more than one entry for some meal_id: length=2889, unique_ids=45
# Week 5 has more than one entry for some meal_id: length=2859, unique_ids=45
# Week 6 has more than one entry for some meal_id: length=2846, unique_ids=45
# Week 7 has more than one entry for some meal_id: length=2795, unique_ids=45
# Week 8 has more than one entry for some meal_id: length=2786, unique_ids=45
# Week 9 has more than one entry for some meal_id: length=2854, unique_ids=45
# Week 10 has more than one entry for some meal_id: length=2859, unique_ids=47
# Week 11 has more than one entry for some meal_id: length=2863, unique_ids=45
# Week 12 has more than one entry for some meal_id: length=2831, unique_ids=45
# Week 13 has more than one entry for some meal_id: length=2838, unique_ids=45
# Week 14 has more than one entry for some meal_id: length=2830, unique_ids=46
# Week 15 has more than one entry for some meal_id: length=2868, unique_ids=46
# Week 16 has more than one entry for some meal_id: length=2850, unique_ids=46
# Week 17 has more than one entry for some meal_id: length=2888, unique_ids=46
# Week 18 has more than one entry for some meal_id: length=2962, unique_ids=48
# Week 19 has more than one entry for some meal_id: length=2939, unique_ids=47
# Week 20 has more than one entry for some meal_id: length=2924, unique_ids=48
# Week 21 has more than one entry for some meal_id: length=2963, unique_ids=47
# Week 22 has more than one entry for some meal_id: length=2923, unique_ids=47
# Week 23 has more than one entry for some meal_id: length=2960, unique_ids=48
# Week 24 has more than one entry for some meal_id: length=2946, unique_ids=48
# Week 25 has more than one entry for some meal_id: length=2972, unique_ids=48
# Week 26 has more than one entry for some meal_id: length=3014, unique_ids=48
# Week 27 has more than one entry for some meal_id: length=3029, unique_ids=48
# Week 28 has more than one entry for some meal_id: length=3044, unique_ids=48
# Week 29 has more than one entry for some meal_id: length=3026, unique_ids=48
# Week 30 has more than one entry for some meal_id: length=3068, unique_ids=48
# Week 31 has more than one entry for some meal_id: length=3082, unique_ids=48
# Week 32 has more than one entry for some meal_id: length=3065, unique_ids=48
# Week 33 has more than one entry for some meal_id: length=3045, unique_ids=48
# Week 34 has more than one entry for some meal_id: length=3016, unique_ids=48
# Week 35 has more than one entry for some meal_id: length=3004, unique_ids=48
# Week 36 has more than one entry for some meal_id: length=3028, unique_ids=48
# Week 37 has more than one entry for some meal_id: length=2997, unique_ids=48
# Week 38 has more than one entry for some meal_id: length=2999, unique_ids=48
# Week 39 has more than one entry for some meal_id: length=3032, unique_ids=48
# Week 40 has more than one entry for some meal_id: length=3070, unique_ids=48
# Week 41 has more than one entry for some meal_id: length=3105, unique_ids=48
# Week 42 has more than one entry for some meal_id: length=3093, unique_ids=48
# Week 43 has more than one entry for some meal_id: length=3104, unique_ids=48
# Week 44 has more than one entry for some meal_id: length=3116, unique_ids=48
# Week 45 has more than one entry for some meal_id: length=3102, unique_ids=48
# Week 46 has more than one entry for some meal_id: length=3065, unique_ids=48
# Week 47 has more than one entry for some meal_id: length=3055, unique_ids=48
# Week 48 has more than one entry for some meal_id: length=3130, unique_ids=48
# Week 49 has more than one entry for some meal_id: length=3129, unique_ids=48
# Week 50 has more than one entry for some meal_id: length=3117, unique_ids=48
# Week 51 has more than one entry for some meal_id: length=3099, unique_ids=48
# Week 52 has more than one entry for some meal_id: length=3193, unique_ids=48
# Week 53 has more than one entry for some meal_id: length=3196, unique_ids=48
# Week 54 has more than one entry for some meal_id: length=3128, unique_ids=48
# Week 55 has more than one entry for some meal_id: length=3179, unique_ids=48
# Week 56 has more than one entry for some meal_id: length=3084, unique_ids=48
# Week 57 has more than one entry for some meal_id: length=3136, unique_ids=48
# Week 58 has more than one entry for some meal_id: length=3130, unique_ids=48
# Week 59 has more than one entry for some meal_id: length=3143, unique_ids=51
# Week 60 has more than one entry for some meal_id: length=3194, unique_ids=51
# Week 61 has more than one entry for some meal_id: length=3188, unique_ids=51
# Week 62 has more than one entry for some meal_id: length=2890, unique_ids=51
# Week 63 has more than one entry for some meal_id: length=3153, unique_ids=51
# Week 64 has more than one entry for some meal_id: length=3200, unique_ids=51
# Week 65 has more than one entry for some meal_id: length=3223, unique_ids=51
# Week 66 has more than one entry for some meal_id: length=3187, unique_ids=51
# Week 67 has more than one entry for some meal_id: length=3205, unique_ids=51
# Week 68 has more than one entry for some meal_id: length=3219, unique_ids=51
# Week 69 has more than one entry for some meal_id: length=3242, unique_ids=51
# Week 70 has more than one entry for some meal_id: length=3260, unique_ids=51
# Week 71 has more than one entry for some meal_id: length=3242, unique_ids=51
# Week 72 has more than one entry for some meal_id: length=3221, unique_ids=51
# Week 73 has more than one entry for some meal_id: length=3208, unique_ids=51
# Week 74 has more than one entry for some meal_id: length=3228, unique_ids=51
# Week 75 has more than one entry for some meal_id: length=3252, unique_ids=51
# Week 76 has more than one entry for some meal_id: length=3210, unique_ids=51
# Week 77 has more than one entry for some meal_id: length=3189, unique_ids=51
# Week 78 has more than one entry for some meal_id: length=3206, unique_ids=51
# Week 79 has more than one entry for some meal_id: length=3208, unique_ids=51
# Week 80 has more than one entry for some meal_id: length=3260, unique_ids=51
# Week 81 has more than one entry for some meal_id: length=3204, unique_ids=51
# Week 82 has more than one entry for some meal_id: length=3250, unique_ids=51
# Week 83 has more than one entry for some meal_id: length=3261, unique_ids=51
# Week 84 has more than one entry for some meal_id: length=3201, unique_ids=51
# Week 85 has more than one entry for some meal_id: length=3254, unique_ids=51
# Week 86 has more than one entry for some meal_id: length=3250, unique_ids=51
# Week 87 has more than one entry for some meal_id: length=3246, unique_ids=51
# Week 88 has more than one entry for some meal_id: length=3263, unique_ids=51
# Week 89 has more than one entry for some meal_id: length=3235, unique_ids=51
# Week 90 has more than one entry for some meal_id: length=3282, unique_ids=51
# Week 91 has more than one entry for some meal_id: length=3289, unique_ids=51
# Week 92 has more than one entry for some meal_id: length=3230, unique_ids=51
# Week 93 has more than one entry for some meal_id: length=3241, unique_ids=51
# Week 94 has more than one entry for some meal_id: length=3303, unique_ids=51
# Week 95 has more than one entry for some meal_id: length=3279, unique_ids=51
# Week 96 has more than one entry for some meal_id: length=3273, unique_ids=51
# Week 97 has more than one entry for some meal_id: length=3259, unique_ids=51
# Week 98 has more than one entry for some meal_id: length=3282, unique_ids=51
# Week 99 has more than one entry for some meal_id: length=3216, unique_ids=51
# Week 100 has more than one entry for some meal_id: length=3309, unique_ids=51
# Week 101 has more than one entry for some meal_id: length=3288, unique_ids=51
# Week 102 has more than one entry for some meal_id: length=3176, unique_ids=51
# Week 103 has more than one entry for some meal_id: length=3029, unique_ids=51
# Week 104 has more than one entry for some meal_id: length=3228, unique_ids=51
# Week 105 has more than one entry for some meal_id: length=3348, unique_ids=51
# Week 106 has more than one entry for some meal_id: length=3347, unique_ids=51
# Week 107 has more than one entry for some meal_id: length=3260, unique_ids=51
# Week 108 has more than one entry for some meal_id: length=3242, unique_ids=51
# Week 109 has more than one entry for some meal_id: length=3299, unique_ids=51
# Week 110 has more than one entry for some meal_id: length=3293, unique_ids=51
# Week 111 has more than one entry for some meal_id: length=3193, unique_ids=51
# Week 112 has more than one entry for some meal_id: length=3175, unique_ids=51
# Week 113 has more than one entry for some meal_id: length=3312, unique_ids=51
# Week 114 has more than one entry for some meal_id: length=3300, unique_ids=51
# Week 115 has more than one entry for some meal_id: length=3286, unique_ids=51
# Week 116 has more than one entry for some meal_id: length=3275, unique_ids=51
# Week 117 has more than one entry for some meal_id: length=3290, unique_ids=51
# Week 118 has more than one entry for some meal_id: length=3278, unique_ids=51
# Week 119 has more than one entry for some meal_id: length=3221, unique_ids=51
# Week 120 has more than one entry for some meal_id: length=3261, unique_ids=51
# Week 121 has more than one entry for some meal_id: length=3298, unique_ids=51
# Week 122 has more than one entry for some meal_id: length=3359, unique_ids=51
# Week 123 has more than one entry for some meal_id: length=3331, unique_ids=51
# Week 124 has more than one entry for some meal_id: length=3274, unique_ids=51
# Week 125 has more than one entry for some meal_id: length=3247, unique_ids=51
# Week 126 has more than one entry for some meal_id: length=3254, unique_ids=51
# Week 127 has more than one entry for some meal_id: length=3255, unique_ids=51
# Week 128 has more than one entry for some meal_id: length=3278, unique_ids=51
# Week 129 has more than one entry for some meal_id: length=3291, unique_ids=51
# Week 130 has more than one entry for some meal_id: length=3258, unique_ids=51
# Week 131 has more than one entry for some meal_id: length=3293, unique_ids=51
# Week 132 has more than one entry for some meal_id: length=3276, unique_ids=51
# Week 133 has more than one entry for some meal_id: length=3324, unique_ids=51
# Week 134 has more than one entry for some meal_id: length=3330, unique_ids=51
# Week 135 has more than one entry for some meal_id: length=3261, unique_ids=51
# Week 136 has more than one entry for some meal_id: length=3273, unique_ids=51
# Week 137 has more than one entry for some meal_id: length=3283, unique_ids=51
# Week 138 has more than one entry for some meal_id: length=3278, unique_ids=51
# Week 139 has more than one entry for some meal_id: length=3279, unique_ids=51
# Week 140 has more than one entry for some meal_id: length=3332, unique_ids=51
# Week 141 has more than one entry for some meal_id: length=3263, unique_ids=51
# Week 142 has more than one entry for some meal_id: length=3238, unique_ids=51
# Week 143 has more than one entry for some meal_id: length=3305, unique_ids=51
# Week 144 has more than one entry for some meal_id: length=3302, unique_ids=51
# Week 145 has more than one entry for some meal_id: length=3268, unique_ids=51

# %%
train_data[train_data['week'] == 1][["meal_id", "center_id", "week"]].groupby(['meal_id', 'center_id']).count()
# Out:
#                    week
# meal_id center_id
# 1062    10            1
#         11            1
#         13            1
#         14            1
#         17            1
# ...                 ...
# 2867    145           1
#         146           1
#         152           1
#         153           1
#         174           1
#
# [2922 rows x 1 columns]

# %%
any(train_data[train_data['week'] == 1][["meal_id", "center_id", "week"]].groupby(['meal_id', 'center_id']).count()['week']>1)
# Out:
# False

# %%
for i in range(146):
    slice = train_data[train_data['week'] == i]
    more_than_one = any(slice[["meal_id", "center_id", "week"]].groupby(['meal_id', 'center_id']).count()['week']>1)
    if more_than_one:
        print(f"Week {i} has more than one entry for some meal_id and center_id combination")

# %%
train_data
# Out:
#         week  center_id  meal_id  checkout_price  base_price  \
# 0          1         55     1885          136.83      152.29
# 1          1         55     1993          136.83      135.83
# 2          1         55     2539          134.86      135.86
# 3          1         55     2139          339.50      437.53
# 4          1         55     2631          243.50      242.50
# ...      ...        ...      ...             ...         ...
# 456543   145         61     1543          484.09      484.09
# 456544   145         61     2304          482.09      482.09
# 456545   145         61     2664          237.68      321.07
# 456546   145         61     2569          243.50      313.34
# 456547   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders   category  \
# 0                           0                  0         177  Beverages
# 1                           0                  0         270  Beverages
# 2                           0                  0         189  Beverages
# 3                           0                  0          54  Beverages
# 4                           0                  0          40  Beverages
# ...                       ...                ...         ...        ...
# 456543                      0                  0          68     Desert
# 456544                      0                  0          42     Desert
# 456545                      0                  0         501      Salad
# 456546                      0                  0         729      Salad
# 456547                      0                  0         162      Salad
#
#         cuisine
# 0          Thai
# 1          Thai
# 2          Thai
# 3        Indian
# 4        Indian
# ...         ...
# 456543   Indian
# 456544   Indian
# 456545  Italian
# 456546  Italian
# 456547  Italian
#
# [456548 rows x 10 columns]

# %%
df = train_data[:]
test_data = df[df['week'] == 145]
train_data = df[df['week'] != 145]
len(test_data)
# Out:
# 3268

# %%
df1, df2 = train_test_split(df, shuffle=False, test_size=len(test_data))
df1.tail()
# Out:
#         week  center_id  meal_id  checkout_price  base_price  \
# 453275   144         61     1543          483.09      483.09
# 453276   144         61     2304          483.09      483.09
# 453277   144         61     2664          243.47      321.07
# 453278   144         61     2569          246.41      314.34
# 453279   144         61     2490          290.03      292.03
#
#         emailer_for_promotion  homepage_featured  num_orders category  cuisine
# 453275                      0                  0         123   Desert   Indian
# 453276                      0                  0          13   Desert   Indian
# 453277                      1                  0         770    Salad  Italian
# 453278                      1                  0         811    Salad  Italian
# 453279                      0                  0         190    Salad  Italian

# %%
df2.head()
# Out:
#         week  center_id  meal_id  checkout_price  base_price  \
# 453280   145         55     1885          156.23      156.23
# 453281   145         55     1993          159.14      158.14
# 453282   145         55     2539          158.11      160.11
# 453283   145         55     2139          292.03      292.03
# 453284   145         55     2631          165.93      165.93
#
#         emailer_for_promotion  homepage_featured  num_orders   category  \
# 453280                      0                  0         121  Beverages
# 453281                      0                  0          54  Beverages
# 453282                      0                  0         135  Beverages
# 453283                      0                  0          15  Beverages
# 453284                      0                  0          96  Beverages
#
#        cuisine
# 453280    Thai
# 453281    Thai
# 453282    Thai
# 453283  Indian
# 453284  Indian

# %%
train_data
# Out:
#         week  center_id  meal_id  checkout_price  base_price  \
# 0          1         55     1885          136.83      152.29
# 1          1         55     1993          136.83      135.83
# 2          1         55     2539          134.86      135.86
# 3          1         55     2139          339.50      437.53
# 4          1         55     2631          243.50      242.50
# ...      ...        ...      ...             ...         ...
# 453275   144         61     1543          483.09      483.09
# 453276   144         61     2304          483.09      483.09
# 453277   144         61     2664          243.47      321.07
# 453278   144         61     2569          246.41      314.34
# 453279   144         61     2490          290.03      292.03
#
#         emailer_for_promotion  homepage_featured  num_orders   category  \
# 0                           0                  0         177  Beverages
# 1                           0                  0         270  Beverages
# 2                           0                  0         189  Beverages
# 3                           0                  0          54  Beverages
# 4                           0                  0          40  Beverages
# ...                       ...                ...         ...        ...
# 453275                      0                  0         123     Desert
# 453276                      0                  0          13     Desert
# 453277                      1                  0         770      Salad
# 453278                      1                  0         811      Salad
# 453279                      0                  0         190      Salad
#
#         cuisine
# 0          Thai
# 1          Thai
# 2          Thai
# 3        Indian
# 4        Indian
# ...         ...
# 453275   Indian
# 453276   Indian
# 453277  Italian
# 453278  Italian
# 453279  Italian
#
# [453280 rows x 10 columns]

# %%
plt.scatter(train_data['week'], train_data['num_orders'], alpha=0.1)

# %%
sns.scatterplot(x='base_price', y='num_orders', hue='category', data=train_data, alpha=0.3)
# Out:
# <Axes: xlabel='base_price', ylabel='num_orders'>

# %%
sns.scatterplot(x='base_price', y='num_orders', data= train_data[train_data['category']=='Beverages'], alpha=0.3)
# Out:
# <Axes: xlabel='base_price', ylabel='num_orders'>

# %%
train_data_beverages = train_data[train_data['category']=='Beverages']
test_data_beverages = test_data[test_data['category']=='Beverages']

# %%
x = train_data_beverages['base_price'].to_numpy().reshape(-1, 1) # reshape for sklearn
y = train_data_beverages['num_orders'].to_numpy()
model = LinearRegression().fit(x, y)
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 1,
#  'coef_': array([-0.96807654]),
#  'rank_': 1,
#  'singular_': array([36934.4513233]),
#  'intercept_': np.float64(536.537717333685)}

# %%
model.coef_, model.intercept_
# Out:
# (array([-0.96807654]), np.float64(536.537717333685))

# %%
train_data_beverages['predictions'] = model.predict(x)
train_data_beverages
# Out:
#         week  center_id  meal_id  checkout_price  base_price  \
# 0          1         55     1885          136.83      152.29
# 1          1         55     1993          136.83      135.83
# 2          1         55     2539          134.86      135.86
# 3          1         55     2139          339.50      437.53
# 4          1         55     2631          243.50      242.50
# ...      ...        ...      ...             ...         ...
# 453245   144         61     1062          153.26      155.26
# 453246   144         61     2707          203.76      235.74
# 453247   144         61     1207          368.63      367.63
# 453248   144         61     1230          368.63      369.63
# 453249   144         61     2322          355.99      355.99
#
#         emailer_for_promotion  homepage_featured  num_orders   category  \
# 0                           0                  0         177  Beverages
# 1                           0                  0         270  Beverages
# 2                           0                  0         189  Beverages
# 3                           0                  0          54  Beverages
# 4                           0                  0          40  Beverages
# ...                       ...                ...         ...        ...
# 453245                      0                  0         472  Beverages
# 453246                      0                  0         392  Beverages
# 453247                      0                  0          96  Beverages
# 453248                      0                  0         136  Beverages
# 453249                      0                  0          69  Beverages
#
#             cuisine  predictions
# 0              Thai   389.109340
# 1              Thai   405.043880
# 2              Thai   405.014838
# 3            Indian   112.975187
# 4            Indian   301.779155
# ...             ...          ...
# 453245      Italian   386.234153
# 453246      Italian   308.323353
# 453247  Continental   180.643737
# 453248  Continental   178.707584
# 453249  Continental   191.912148
#
# [126993 rows x 11 columns]

# %%
sns.scatterplot(x='base_price', y='num_orders', hue='category', data=train_data_beverages)
sns.lineplot(data=train_data_beverages, x='base_price', y='predictions', hue='category', palette=['red'])
# Out:
# <Axes: xlabel='base_price', ylabel='num_orders'>

# %%
sns.regplot(data=train_data_beverages, x='base_price', y='num_orders', scatter=False)
# Out:
# <Axes: xlabel='base_price', ylabel='num_orders'>

# %%
# MSE
# mean_squared_error = np.sum((y-y_hat.T)**2) / len(y)

#test_data_beverages['predictions'] = model.predict(test_data_beverages['base_price'].values.reshape(-1, 1))
test_data_beverages['predictions'] = model.predict(test_data_beverages['base_price'].to_numpy().reshape(-1, 1))

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(test_data_beverages['num_orders'], test_data_beverages['predictions']))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f' % r2_score(test_data_beverages['num_orders'], test_data_beverages['predictions']))
# Out:
# Mean squared error: 96257.36
# Coefficient of determination: 0.02

# %%
x_f = np.array([[1], [2], [3]])
y_f = np.array([1, 2, 3])

model_f = LinearRegression().fit(x_f, y_f)
model_f.coef_ = np.array([1.0])
model_f.intercept_ = np.array([0.0])
model_f.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 1,
#  'coef_': array([1.]),
#  'rank_': 1,
#  'singular_': array([1.41421356]),
#  'intercept_': array([0.])}

# %%
x_f = np.array([[1], [2], [3]])
y_hat = model_f.intercept_ + x_f * model_f.coef_
x_f, y_hat
# Out:
# (array([[1],
#         [2],
#         [3]]),
#  array([[1.],
#         [2.],
#         [3.]]))

# %%
mean_squared_error_manual = np.sum((y_f - y_hat.T) ** 2) / len(y_f)
mean_squared_error_manual
# Out:
# np.float64(0.0)

# %%
sns.scatterplot(x='checkout_price', y='num_orders', hue='category', data=test_data_beverages)
sns.lineplot(data=test_data_beverages, x='base_price', y='predictions', hue='category', palette=['red'])
sns.lineplot(data=test_data_beverages, x='base_price', y=test_data_beverages['num_orders'].mean(),hue='category', palette=['orange'])
# Out:
# <Axes: xlabel='checkout_price', ylabel='num_orders'>

# %%
mean_squared_error(test_data_beverages['num_orders'], [test_data_beverages['num_orders'].mean()]*len(test_data_beverages))
# Out:
# 97973.8176033328

# %%
model_copy = deepcopy(model)
model_copy.coef_
# Out:
# array([-0.96807654])

# %%
model_copy.coef_ = np.array([-0.99])

train_predictions_samples = train_data_beverages[["base_price", "num_orders"]]
train_predictions_samples["exp_best"] = train_data_beverages["predictions"]
train_predictions_samples["exp_0"] = model_copy.predict(x)

train_predictions_samples
# Out:
#         base_price  num_orders    exp_best       exp_0
# 0           152.29         177  389.109340  385.770617
# 1           135.83         270  405.043880  402.066017
# 2           135.86         189  405.014838  402.036317
# 3           437.53          54  112.975187  103.383017
# 4           242.50          40  301.779155  296.462717
# ...            ...         ...         ...         ...
# 453245      155.26         472  386.234153  382.830317
# 453246      235.74         392  308.323353  303.155117
# 453247      367.63          96  180.643737  172.584017
# 453248      369.63         136  178.707584  170.604017
# 453249      355.99          69  191.912148  184.107617
#
# [126993 rows x 4 columns]

# %%
sns.lineplot(x='base_price', y = 'value', hue='variable', data = pd.melt(train_predictions_samples.drop(["num_orders"], axis=1), ['base_price']))
# Out:
# <Axes: xlabel='base_price', ylabel='value'>

# %%
pd.melt(train_predictions_samples, ['base_price'])
# Out:
#         base_price    variable       value
# 0           152.29  num_orders  177.000000
# 1           135.83  num_orders  270.000000
# 2           135.86  num_orders  189.000000
# 3           437.53  num_orders   54.000000
# 4           242.50  num_orders   40.000000
# ...            ...         ...         ...
# 380974      155.26       exp_0  382.830317
# 380975      235.74       exp_0  303.155117
# 380976      367.63       exp_0  172.584017
# 380977      369.63       exp_0  170.604017
# 380978      355.99       exp_0  184.107617
#
# [380979 rows x 3 columns]

# %%
coefs = [-4.2, -2.3, -1.7, -0.99, -0.98, -0.97, -0.84, -0.64, -0.5, -0.2, 0.01, 0.2, 0.45, 0.76, 0.99, 1.7, 2.3]

x_test = test_data_beverages["base_price"].to_numpy().reshape(-1,1)
test_predictions_samples = test_data_beverages[["base_price", "num_orders"]]

models = []
for coef in coefs:
    new_model = deepcopy(model)
    new_model.coef_ = np.array([coef])
    models.append(new_model)
    
for  i in range(len(models)):
    test_predictions_samples[f"exp_{i}"] = models[i].predict(x_test)
    
test_predictions_samples
# Out:
#         base_price  num_orders        exp_0       exp_1       exp_2  \
# 453280      156.23         121  -119.628283  177.208717  270.946717
# 453281      158.14          54  -127.650283  172.815717  267.699717
# 453282      160.11         135  -135.924283  168.284717  264.350717
# 453283      292.03          15  -689.988283 -135.131283   40.086717
# 453284      165.93          96  -160.368283  154.898717  254.456717
# ...            ...         ...          ...         ...         ...
# 456514      153.26         378  -107.154283  184.039717  275.995717
# 456515      234.74         312  -449.370283   -3.364283  137.479717
# 456516      359.87         134  -974.916283 -291.163283  -75.241283
# 456517      367.63          42 -1007.508283 -309.011283  -88.433283
# 456518      359.87          82  -974.916283 -291.163283  -75.241283
#
#              exp_3       exp_4       exp_5       exp_6       exp_7  \
# 453280  381.870017  383.432317  384.994617  405.304517  436.550517
# 453281  379.979117  381.560517  383.141917  403.700117  435.328117
# 453282  378.028817  379.629917  381.231017  402.045317  434.067317
# 453283  247.428017  250.348317  253.268617  291.232517  349.638517
# 453284  372.267017  373.926317  375.585617  397.156517  430.342517
# ...            ...         ...         ...         ...         ...
# 456514  384.810317  386.342917  387.875517  407.799317  438.451317
# 456515  304.145117  306.492517  308.839917  339.356117  386.304117
# 456516  180.266417  183.865117  187.463817  234.246917  306.220917
# 456517  172.584017  176.260317  179.936617  227.728517  301.254517
# 456518  180.266417  183.865117  187.463817  234.246917  306.220917
#
#              exp_8       exp_9      exp_10      exp_11      exp_12  \
# 453280  458.422717  505.291717  538.100017  567.783717  606.841217
# 453281  457.467717  504.909717  538.119117  568.165717  607.700717
# 453282  456.482717  504.515717  538.138817  568.559717  608.587217
# 453283  390.522717  478.131717  539.458017  594.943717  667.951217
# 453284  453.572717  503.351717  538.197017  569.723717  611.206217
# ...            ...         ...         ...         ...         ...
# 456514  459.907717  505.885717  538.070317  567.189717  605.504717
# 456515  419.167717  489.589717  538.885117  583.485717  642.170717
# 456516  356.602717  464.563717  540.136417  608.511717  698.479217
# 456517  352.722717  463.011717  540.214017  610.063717  701.971217
# 456518  356.602717  464.563717  540.136417  608.511717  698.479217
#
#             exp_13      exp_14       exp_15       exp_16
# 453280  655.272517  691.205417   802.128717   895.866717
# 453281  656.724117  693.096317   805.375717   900.259717
# 453282  658.221317  695.046617   808.724717   904.790717
# 453283  758.480517  825.647417  1032.988717  1208.206717
# 453284  662.644517  700.808417   818.618717   918.176717
# ...            ...         ...          ...          ...
# 456514  653.015317  688.265117   797.079717   889.035717
# 456515  714.940117  768.930317   935.595717  1076.439717
# 456516  810.038917  892.809017  1148.316717  1364.238717
# 456517  815.936517  900.491417  1161.508717  1382.086717
# 456518  810.038917  892.809017  1148.316717  1364.238717
#
# [897 rows x 19 columns]

# %%
sns.lineplot(x='base_price', y='value', hue='variable', data = pd.melt(test_predictions_samples.drop(["num_orders"], axis=1), ['base_price']))
# Out:
# <Axes: xlabel='base_price', ylabel='value'>

# %%
loses = []

for i, model in enumerate(models):
    loses.append(mean_squared_error(test_data_beverages["num_orders"], test_predictions_samples[f"exp_{i}"]))
loses
# Out:
# [645311.1514756292,
#  172218.519587594,
#  111915.59958404092,
#  95801.8308957515,
#  96002.53122266044,
#  96215.11084999927,
#  100059.66234452493,
#  109894.52609335439,
#  119606.20421985113,
#  148257.28134607794,
#  174674.40071464796,
#  203089.7381162399,
#  247011.95519688458,
#  311786.7371500369,
#  367222.4919080531,
#  577991.4821304174,
#  802791.772444456]

# %%
coefs
# Out:
# [-4.2,
#  -2.3,
#  -1.7,
#  -0.99,
#  -0.98,
#  -0.97,
#  -0.84,
#  -0.64,
#  -0.5,
#  -0.2,
#  0.01,
#  0.2,
#  0.45,
#  0.76,
#  0.99,
#  1.7,
#  2.3]

# %%
plt.plot(np.array(coefs), np.array(loses), label = 'MSE')

# %%
from sklearn import preprocessing
from copy import deepcopy

X_train = deepcopy(x)
scaler = preprocessing.StandardScaler().fit(X_train)
scaler.mean_, scaler.scale_
# Out:
# (array([226.86952793]), array([103.64342599]))

# %%
X_scaled = scaler.transform(X_train)
X_scaled
# Out:
# array([[-0.71957799],
#        [-0.87839173],
#        [-0.87810227],
#        ...,
#        [ 1.35812253],
#        [ 1.37741946],
#        [ 1.2458144 ]], shape=(126993, 1))

# %%
model_scaled = LinearRegression().fit(X_scaled, y)
model_scaled.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 1,
#  'coef_': array([-100.33476972]),
#  'rank_': 1,
#  'singular_': array([356.36077225]),
#  'intercept_': np.float64(316.9106486184278)}

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 1,
#  'coef_': array([2.3]),
#  'rank_': 1,
#  'singular_': array([36934.4513233]),
#  'intercept_': np.float64(536.537717333685)}

# %%
test_data_beverages["predictions_normed"]  = model_scaled.predict(test_data_beverages['base_price'].to_numpy().reshape(-1, 1))
mean_squared_error(test_data_beverages['num_orders'], test_data_beverages['predictions_normed'])
# Out:
# 594200437.792273
